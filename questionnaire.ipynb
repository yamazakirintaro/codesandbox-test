# %% [markdown]
# <a href="https://colab.research.google.com/github/yamazakirintaro/codesandbox-test/blob/main/questionnaire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # データダウンロード

# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir("/content/drive/My Drive/NTTcompetition/")

# %%
# !pwd
# Out:
# /content/drive/My Drive/NTTcompetition

# %%
columns=["time_stamp", 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness', 'mogi_price','mogi_brand_cognition', 'mogi_package_impression', 'mogi_appetite', 'mogi_willingness_to_buy', 'mogi_dryness', 'mogi_stickiness', 'mogi_juicy', 'mogi_saltiness', 'mogi_seasoned_flavour', 'mogi_flavour_heaviness', 'mogi_flavour_lightness', 'mogi_soya_taste', 'mogi_soya_smell','mogi_meat_similarity', 'mogi_meat_taste_similarity','mogi_meat_texture_similarity','mogi_meat_smell_similarity', 'mogi_deliciousness', 'mujirushi_price','mujirushi_brand_cognition', 'mujirushi_package_impression', 'mujirushi_appetite', 'mujirushi_willingness_to_buy', 'mujirushi_dryness', 'mujirushi_stickiness', 'mujirushi_juicy', 'mujirushi_saltiness', 'mujirushi_seasoned_flavour', 'mujirushi_flavour_heaviness', 'mujirushi_flavour_lightness', 'mujirushi_soya_taste', 'mujirushi_soya_smell','mujirushi_meat_similarity', 'mujirushi_meat_taste_similarity','mujirushi_meat_texture_similarity','mujirushi_meat_smell_similarity', 'mujirushi_deliciousness',  'carlota_price','carlota_brand_cognition', 'carlota_package_impression', 'carlota_appetite', 'carlota_willingness_to_buy', 'carlota_dryness', 'carlota_stickiness', 'carlota_juicy', 'carlota_saltiness', 'carlota_seasoned_flavour', 'carlota_flavour_heaviness', 'carlota_flavour_lightness', 'carlota_quinoa_taste', 'carlota_quinoa_smell','carlota_meat_similarity', 'carlota_meat_taste_similarity','carlota_meat_texture_similarity','carlota_meat_smell_similarity', 'carlota_deliciousness', 'topvalue_price','topvalue_brand_cognition', 'topvalue_package_impression', 'topvalue_appetite', 'topvalue_willingness_to_buy', 'topvalue_dryness', 'topvalue_stickiness', 'topvalue_juicy', 'topvalue_saltiness', 'topvalue_seasoned_flavour', 'topvalue_flavour_heaviness', 'topvalue_flavour_lightness', 'topvalue_soya_taste', 'topvalue_soya_smell','topvalue_meat_similarity', 'topvalue_meat_taste_similarity','topvalue_meat_texture_similarity','topvalue_meat_smell_similarity', 'topvalue_deliciousness','willingness_to_buy_fake_meat', 'willingness_to_buy_A', 'willingness_to_buy_B', 'willingness_to_buy_C', 'willingness_to_buy_D','free_writing']

# %%
questionnaire_result=pd.read_csv("questionnaire.csv",header=0)

# %%
questionnaire_result.columns=columns

# %%
questionnaire_result
# Out:
#                       time_stamp sweet_fondness spicy_fondness salty_fondness  \
# 0    2022/03/16 8:12:39 午後 GMT+9          4. 好む        2. 少し苦手     3. どちらでもない
# 1    2022/03/16 8:43:13 午後 GMT+9     3. どちらでもない     3. どちらでもない     3. どちらでもない
# 2    2022/03/16 8:44:04 午後 GMT+9        2. 少し苦手        2. 少し苦手          4. 好む
# 3    2022/03/16 8:48:46 午後 GMT+9          4. 好む     3. どちらでもない     3. どちらでもない
# 4    2022/03/16 8:49:02 午後 GMT+9          4. 好む          4. 好む       5. とても好む
# 5    2022/03/16 8:49:06 午後 GMT+9       5. とても好む          4. 好む          4. 好む
# 6    2022/03/16 8:49:53 午後 GMT+9       5. とても好む          1. 苦手     3. どちらでもない
# 7    2022/03/16 8:50:10 午後 GMT+9          4. 好む          4. 好む          4. 好む
# 8   2022/03/16 11:28:13 午後 GMT+9       5. とても好む          4. 好む       5. とても好む
# 9   2022/03/16 11:30:14 午後 GMT+9          4. 好む     3. どちらでもない          4. 好む
# 10  2022/03/16 11:48:04 午後 GMT+9          4. 好む     3. どちらでもない       5. とても好む
#
# ...

# %% [markdown]
# #数値化とスケーリング(前処理)

# %% [markdown]
# 数値化

# %%
import re

# %%
#タイムスタンプと自由記述を削除
questionnaire_result=questionnaire_result.drop(['time_stamp','free_writing'],axis=1)

# %%
questionnaire_result=questionnaire_result.replace(to_replace=r'^[1].*' ,value=1, regex=True)
questionnaire_result=questionnaire_result.replace(to_replace=r'^[2].*' ,value=2, regex=True)
questionnaire_result=questionnaire_result.replace(to_replace=r'^[3].*' ,value=3, regex=True)
questionnaire_result=questionnaire_result.replace(to_replace=r'^[4].*' ,value=4, regex=True)
questionnaire_result=questionnaire_result.replace(to_replace=r'^[5].*' ,value=5, regex=True)
questionnaire_result.head()
# Out:
#   sweet_fondness spicy_fondness salty_fondness seasoned_flavour_fondness  \
# 0              4              2              3                         4
# 1              3              3              3                         3
# 2              2              2              4                         4
# 3              4              3              3                         4
# 4              4              4              5                         5
#
#   bitter_fondness light_seasoning_fondness heavy_seasoning_fondness  \
# 0               4                        3                        4
# 1               3                        3                        3
# 2               3                        3                        4
# 3               4                        5                        2
# 4               1                        2                        5
#
#   soya_bean_fondness vegetable_fondness meat_fondness  ...  \
# ...

# %% [markdown]
# 標準正規化

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
questionnaire_result_scaled=sc.fit_transform(questionnaire_result)

# %%
columns=['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness', 'mogi_price','mogi_brand_cognition', 'mogi_package_impression', 'mogi_appetite', 'mogi_willingness_to_buy', 'mogi_dryness', 'mogi_stickiness', 'mogi_juicy', 'mogi_saltiness', 'mogi_seasoned_flavour', 'mogi_flavour_heaviness', 'mogi_flavour_lightness', 'mogi_soya_taste', 'mogi_soya_smell','mogi_meat_similarity', 'mogi_meat_taste_similarity','mogi_meat_texture_similarity','mogi_meat_smell_similarity', 'mogi_deliciousness', 'mujirushi_price','mujirushi_brand_cognition', 'mujirushi_package_impression', 'mujirushi_appetite', 'mujirushi_willingness_to_buy', 'mujirushi_dryness', 'mujirushi_stickiness', 'mujirushi_juicy', 'mujirushi_saltiness', 'mujirushi_seasoned_flavour', 'mujirushi_flavour_heaviness', 'mujirushi_flavour_lightness', 'mujirushi_soya_taste', 'mujirushi_soya_smell','mujirushi_meat_similarity', 'mujirushi_meat_taste_similarity','mujirushi_meat_texture_similarity','mujirushi_meat_smell_similarity', 'mujirushi_deliciousness',  'carlota_price','carlota_brand_cognition', 'carlota_package_impression', 'carlota_appetite', 'carlota_willingness_to_buy', 'carlota_dryness', 'carlota_stickiness', 'carlota_juicy', 'carlota_saltiness', 'carlota_seasoned_flavour', 'carlota_flavour_heaviness', 'carlota_flavour_lightness', 'carlota_quinoa_taste', 'carlota_quinoa_smell','carlota_meat_similarity', 'carlota_meat_taste_similarity','carlota_meat_texture_similarity','carlota_meat_smell_similarity', 'carlota_deliciousness', 'topvalue_price','topvalue_brand_cognition', 'topvalue_package_impression', 'topvalue_appetite', 'topvalue_willingness_to_buy', 'topvalue_dryness', 'topvalue_stickiness', 'topvalue_juicy', 'topvalue_saltiness', 'topvalue_seasoned_flavour', 'topvalue_flavour_heaviness', 'topvalue_flavour_lightness', 'topvalue_soya_taste', 'topvalue_soya_smell','topvalue_meat_similarity', 'topvalue_meat_taste_similarity','topvalue_meat_texture_similarity','topvalue_meat_smell_similarity', 'topvalue_deliciousness','willingness_to_buy_fake_meat', 'willingness_to_buy_A', 'willingness_to_buy_B', 'willingness_to_buy_C', 'willingness_to_buy_D']
questionnaire_result_scaled=pd.DataFrame(data=questionnaire_result_scaled,columns=columns)

# %%
questionnaire_result_scaled
# Out:
#     sweet_fondness  spicy_fondness  salty_fondness  seasoned_flavour_fondness  \
# 0         0.000000       -1.048809       -1.147079                  -0.316228
# 1        -1.172604        0.000000       -1.147079                  -2.055480
# 2        -2.345208       -1.048809        0.114708                  -0.316228
# 3         0.000000        0.000000       -1.147079                  -0.316228
# 4         0.000000        1.048809        1.376494                   1.423025
# 5         1.172604        1.048809        0.114708                  -0.316228
# 6         1.172604       -2.097618       -1.147079                  -0.316228
# 7         0.000000        1.048809        0.114708                  -0.316228
# 8         1.172604        1.048809        1.376494                   1.423025
# 9         0.000000        0.000000        0.114708                   1.423025
# 10        0.000000        0.000000        1.376494                  -0.316228
#
# ...

# %% [markdown]
# #仮説0の検証

# %% [markdown]
# 仮説0：消費者が食べたことのない代替肉商品を選ぶときには、ブランドの認識度や価格などが重要指標となるだろう

# %% [markdown]
# 検証方法：説明変数となる指標を[価格,ブランド認識度,パッケージの印象,見た目]として、目的変数に対応する指標を[現時点でこの商品を購入したいか]にして、重回帰分析を行い、それぞれの指標の係数を見る。

# %%
#各人のそれぞれの商品に対する食前の感想が各行に入った、44行5列の行列を作成する。
columns_0=["price","brand_congnition","package_impression","dish_impression","willingness_to_buy"]
table_mogi_0=questionnaire_result.loc[:,['mogi_price','mogi_brand_cognition','mogi_package_impression','mogi_appetite','mogi_willingness_to_buy']]
table_mogi_0.columns=columns_0
table_mujirushi_0=questionnaire_result.loc[:,['mujirushi_price','mujirushi_brand_cognition','mujirushi_package_impression','mujirushi_appetite','mujirushi_willingness_to_buy']]
table_mujirushi_0.columns=columns_0
table_carlota_0=questionnaire_result.loc[:,['carlota_price','carlota_brand_cognition','carlota_package_impression','carlota_appetite','carlota_willingness_to_buy']]
table_carlota_0.columns=columns_0
table_topvalue_0=questionnaire_result.loc[:,['topvalue_price','topvalue_brand_cognition','topvalue_package_impression','topvalue_appetite','topvalue_willingness_to_buy']]
table_topvalue_0.columns=columns_0

# %%
table_0=pd.concat([table_mogi_0,table_mujirushi_0,table_carlota_0,table_topvalue_0],axis=0)

# %%
table_0
# Out:
#    price brand_congnition package_impression dish_impression  \
# 0      2                1                  3               3
# 1      2                1                  3               3
# 2      1                1                  4               3
# 3      2                1                  5               4
# 4      2                1                  4               4
# 5      2                1                  4               4
# 6      2                1                  4               4
# 7      2                1                  4               3
# 8      2                1                  3               4
# 9      3                1                  5               5
# 10     4                1                  4               4
# 0      2                2                  4               3
# 1      3                1                  3               3
# 2      2                5                  4               4
# ...

# %%
plt.scatter(table_0["dish_impression"],table_0["willingness_to_buy"])

# %%
X=np.array(table_0.loc[:,["price","brand_congnition","package_impression","dish_impression"]])
y=np.array(table_0.loc[:,"willingness_to_buy"])

# %%
reg_0 = LinearRegression().fit(X, y)

# %%
reg_0.coef_
# Out:
# array([0.29184046, 0.00658594, 0.27014413, 0.41323624])

# %% [markdown]
# 食べる前にその商品を買いたいかどうかに重要な項目。1位が「商品そのものの見た目」2位が「価格」、3位が僅差で「パッケージの見た目」。「ブランド認知度」は影響がなさそうだった。

# %%
reg_0.intercept_
# Out:
# -0.2815911491455445

# %%
#画像描画
#説明変数一つづつ回帰直線を引く
#相関係数
#スケーリング処理

# %%
#標準正規化
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
table_0_scaled=sc.fit_transform(table_0)
table_0_scaled=pd.DataFrame(data=table_0_scaled,columns=columns_0)
table_0_scaled
# Out:
#        price  brand_congnition  package_impression  dish_impression  \
# 0  -0.264649         -0.890637           -1.137578        -0.200731
# 1  -0.264649         -0.890637           -1.137578        -0.200731
# 2  -1.235027         -0.890637           -0.072611        -0.200731
# 3  -0.264649         -0.890637            0.992355         0.602194
# 4  -0.264649         -0.890637           -0.072611         0.602194
# 5  -0.264649         -0.890637           -0.072611         0.602194
# 6  -0.264649         -0.890637           -0.072611         0.602194
# 7  -0.264649         -0.890637           -0.072611        -0.200731
# 8  -0.264649         -0.890637           -1.137578         0.602194
# 9   0.705730         -0.890637            0.992355         1.405119
# 10  1.676108         -0.890637           -0.072611         0.602194
# 11 -0.264649         -0.338693           -0.072611        -0.200731
# 12  0.705730         -0.890637           -1.137578        -0.200731
# ...

# %%
X_0_scaled=np.array(table_0_scaled.loc[:,["price","brand_congnition","package_impression","dish_impression"]])
y_0_scaled=np.array(table_0_scaled.loc[:,"willingness_to_buy"])
reg_0_scaled = LinearRegression().fit(X_0_scaled, y_0_scaled)
print("係数は",reg_0_scaled.coef_)
print("切片は",reg_0_scaled.intercept_)
# Out:
# 係数は [0.30113825 0.01194771 0.25399266 0.51532941]
# 切片は 2.174938297868323e-16

# %% [markdown]
# 標準正規化した結果と元の結果はそこまで変わらなかった

# %% [markdown]
# #仮説1：「肉の類似度に重要な項目」の検証

# %% [markdown]
# 一旦、肉との類似度を目的変数に、[見た目の魅力度、味類似度、匂い類似度、食感類似度]を説明変数にして重回帰分析(ラッソ回帰で関係ない項目を除外するのがいいかもしれない)

# %%
#肉の類似性に関する、44行5列の行列を作成する。
columns_1=['dish_impression','taste_similarity','texture_similarity','smell_similarity','meat_similarity']
table_mogi_1=questionnaire_result.loc[:,['mogi_appetite','mogi_meat_taste_similarity','mogi_meat_texture_similarity','mogi_meat_smell_similarity','mogi_meat_similarity']]
table_mogi_1.columns=columns_1
table_mujirushi_1=questionnaire_result.loc[:,['mujirushi_appetite','mujirushi_meat_taste_similarity','mujirushi_meat_texture_similarity','mujirushi_meat_smell_similarity','mujirushi_meat_similarity']]
table_mujirushi_1.columns=columns_1
table_carlota_1=questionnaire_result.loc[:,['carlota_appetite','carlota_meat_taste_similarity','carlota_meat_texture_similarity','carlota_meat_smell_similarity','carlota_meat_similarity']]
table_carlota_1.columns=columns_1
table_topvalue_1=questionnaire_result.loc[:,['topvalue_appetite','topvalue_meat_taste_similarity','topvalue_meat_texture_similarity','topvalue_meat_smell_similarity','topvalue_meat_similarity']]
table_topvalue_1.columns=columns_1

# %%
table_1=pd.concat([table_mogi_1,table_mujirushi_1,table_carlota_1,table_topvalue_1])

# %%
table_1
# Out:
#    dish_impression taste_similarity texture_similarity smell_similarity  \
# 0                3                2                  3                1
# 1                3                3                  3                3
# 2                3                3                  3                4
# 3                4                2                  3                2
# 4                4                2                  2                3
# 5                4                4                  3                3
# 6                4                2                  3                3
# 7                3                4                  3                4
# 8                4                2                  3                3
# 9                5                2                  4                2
# 10               4                2                  3                3
# 0                3                1                  1                1
# ...

# %%
X=np.array(table_1.loc[:,['dish_impression','taste_similarity','texture_similarity','smell_similarity']])
y=np.array(table_1.loc[:,'meat_similarity'])

# %%
reg_1 = LinearRegression().fit(X, y)

# %%
print("係数は",reg_1.coef_)
print("切片は",reg_1.intercept_)
# Out:
# 係数は [ 0.13238886  0.59546693  0.41596913 -0.03273161]
# 切片は -0.21959886070761714

# %% [markdown]
# 肉との類似度に大事な要素について。1位が「味の類似度」、2位が「食感の類似度」。今回の調査範囲では、匂いよりも味と食感が肉との類似度に大きく影響している。

# %%
#標準正規化
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
table_1_scaled=sc.fit_transform(table_1)
table_1_scaled=pd.DataFrame(data=table_1_scaled,columns=columns_1)
table_1_scaled
# Out:
#     dish_impression  taste_similarity  texture_similarity  smell_similarity  \
# 0         -0.200731          -0.21682            0.264649         -1.023487
# 1         -0.200731           0.84319            0.264649          0.934488
# 2         -0.200731           0.84319            0.264649          1.913475
# 3          0.602194          -0.21682            0.264649         -0.044499
# 4          0.602194          -0.21682           -0.705730          0.934488
# 5          0.602194           1.90320            0.264649          0.934488
# 6          0.602194          -0.21682            0.264649          0.934488
# 7         -0.200731           1.90320            0.264649          1.913475
# 8          0.602194          -0.21682            0.264649          0.934488
# 9          1.405119          -0.21682            1.235027         -0.044499
# 10         0.602194          -0.21682            0.264649          0.934488
# ...

# %%
X_1_scaled=np.array(table_1_scaled.loc[:,['dish_impression','taste_similarity','texture_similarity','smell_similarity']])
y_1_scaled=np.array(table_1_scaled.loc[:,'meat_similarity'])
reg_1_scaled = LinearRegression().fit(X_1_scaled, y_1_scaled)
print("係数は",reg_1_scaled.coef_)
print("切片は",reg_1_scaled.intercept_)
# Out:
# 係数は [0.35142837 0.37518905]
# 切片は 5.3651904732857317e-17

# %% [markdown]
# 個別の定性的な分析をするのがいいかも。機械学習ではなく。

# %% [markdown]
# #仮説3:「商品の美味しさと肉との類似度の関係」

# %%
columns_3=['meat_similarity','deliciousness']
table_mogi_3=questionnaire_result.loc[:,['mogi_meat_similarity','mogi_deliciousness']]
table_mogi_3.columns=columns_3
table_mujirushi_3=questionnaire_result.loc[:,['mujirushi_meat_similarity','mujirushi_deliciousness']]
table_mujirushi_3.columns=columns_3
table_carlota_3=questionnaire_result.loc[:,['carlota_meat_similarity','carlota_deliciousness']]
table_carlota_3.columns=columns_3
table_topvalue_3=questionnaire_result.loc[:,['topvalue_meat_similarity','topvalue_deliciousness']]
table_topvalue_3.columns=columns_3

# %%
table_3=pd.concat([table_mogi_3,table_mujirushi_3,table_carlota_3,table_topvalue_3])
table_3
# Out:
#    meat_similarity deliciousness
# 0                4             4
# 1                3             4
# 2                4             4
# 3                3             4
# 4                2             5
# 5                4             4
# 6                4             4
# 7                4             4
# 8                2             3
# 9                3             4
# 10               2             3
# 0                1             2
# 1                2             3
# 2                2             3
# 3                4             3
# 4                4             2
# 5                3             3
# 6                4             3
# 7                2             3
# 8                3             2
# 9                2             3
# 10               3             4
# 0                2             3
# 1                1             1
# 2                1             3
# 3                1             1
# 4                1             1
# ...

# %%
plt.scatter(table_3.loc[:,"meat_similarity"],table_3.loc[:,"deliciousness"])

# %%
X=np.array(table_3.loc[:,["meat_similarity"]])
y=np.array(table_3.loc[:,["deliciousness"]])

# %%
reg3 = LinearRegression().fit(X, y)

# %%
print("係数は",reg3.coef_)
print("切片は",reg3.intercept_)
# Out:
# 係数は [[0.76124031]]
# 切片は [1.11860465]

# %%
X.T[0]
# Out:
# array([4, 3, 4, 3, 2, 4, 4, 4, 2, 3, 2, 1, 2, 2, 4, 4, 3, 4, 2, 3, 2, 3,
#        2, 1, 1, 1, 1, 2, 1, 1, 1, 1, 2, 4, 1, 3, 4, 3, 4, 2, 2, 4, 4, 4],
#       dtype=object)

# %%
Xy=np.vstack([X.T[0],y.T[0]])

# %%
Xy
# Out:
# array([[4, 3, 4, 3, 2, 4, 4, 4, 2, 3, 2, 1, 2, 2, 4, 4, 3, 4, 2, 3, 2, 3,
#         2, 1, 1, 1, 1, 2, 1, 1, 1, 1, 2, 4, 1, 3, 4, 3, 4, 2, 2, 4, 4, 4],
#        [4, 4, 4, 4, 5, 4, 4, 4, 3, 4, 3, 2, 3, 3, 3, 2, 3, 3, 3, 2, 3, 4,
#         3, 1, 3, 1, 1, 2, 1, 2, 1, 1, 2, 4, 1, 4, 5, 4, 4, 5, 3, 5, 5, 4]],
#       dtype=object)

# %%
np.corrcoef(X.T[0].astype(np.int32),y.T[0].astype(np.int32))
# Out:
# array([[1.        , 0.70878606],
#        [0.70878606, 1.        ]])

# %% [markdown]
# 相関係数0.7。結構高い。肉の類似度は代替肉製品の美味しさに重要である。この結果は最初のストーリーで紹介してもいいかも。自社の、代替肉を肉の味に近づけたい、という思いの後押しになる

# %% [markdown]
# 肉との類似度と肉の味との類似度の相関係数

# %%
columns_3=['meat_taste_similarity','meat_similarity']
table_mogi_3=questionnaire_result.loc[:,['mogi_meat_taste_similarity','mogi_meat_similarity']]
table_mogi_3.columns=columns_3
table_mujirushi_3=questionnaire_result.loc[:,['mujirushi_meat_taste_similarity','mujirushi_meat_similarity']]
table_mujirushi_3.columns=columns_3
table_carlota_3=questionnaire_result.loc[:,['carlota_meat_taste_similarity','carlota_meat_similarity']]
table_carlota_3.columns=columns_3
table_topvalue_3=questionnaire_result.loc[:,['topvalue_meat_taste_similarity','topvalue_meat_similarity']]
table_topvalue_3.columns=columns_3
table_3=pd.concat([table_mogi_3,table_mujirushi_3,table_carlota_3,table_topvalue_3])
X=np.array(table_3.loc[:,["meat_taste_similarity"]])
y=np.array(table_3.loc[:,["meat_similarity"]])
np.corrcoef(X.T[0].astype(np.int32),y.T[0].astype(np.int32))
# Out:
# array([[1.       , 0.7655103],
#        [0.7655103, 1.       ]])

# %% [markdown]
# 肉との類似度と肉の食感との類似度の相関係数

# %%
columns_3=['meat_texture_similarity','meat_similarity']
table_mogi_3=questionnaire_result.loc[:,['mogi_meat_texture_similarity','mogi_meat_similarity']]
table_mogi_3.columns=columns_3
table_mujirushi_3=questionnaire_result.loc[:,['mujirushi_meat_texture_similarity','mujirushi_meat_similarity']]
table_mujirushi_3.columns=columns_3
table_carlota_3=questionnaire_result.loc[:,['carlota_meat_texture_similarity','carlota_meat_similarity']]
table_carlota_3.columns=columns_3
table_topvalue_3=questionnaire_result.loc[:,['topvalue_meat_texture_similarity','topvalue_meat_similarity']]
table_topvalue_3.columns=columns_3
table_3=pd.concat([table_mogi_3,table_mujirushi_3,table_carlota_3,table_topvalue_3])
X=np.array(table_3.loc[:,["meat_texture_similarity"]])
y=np.array(table_3.loc[:,["meat_similarity"]])
np.corrcoef(X.T[0].astype(np.int32),y.T[0].astype(np.int32))
# Out:
# array([[1.        , 0.72770039],
#        [0.72770039, 1.        ]])

# %% [markdown]
# #仮説4：「商品の美味しさに重要な要素がある」の検証

# %% [markdown]
# 肉との類似度以外の項目で美味しさの項目

# %%
columns_4=['appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_similarity','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness']
table_mogi_4 = questionnaire_result.loc[:, ['mogi_appetite','mogi_dryness', 'mogi_stickiness', 'mogi_juicy', 'mogi_saltiness', 'mogi_seasoned_flavour', 'mogi_flavour_heaviness', 'mogi_flavour_lightness', 'mogi_soya_taste', 'mogi_soya_smell','mogi_meat_similarity','mogi_meat_taste_similarity','mogi_meat_texture_similarity','mogi_meat_smell_similarity', 'mogi_deliciousness']]
table_mogi_4.columns=columns_4
table_mujirushi_4 = questionnaire_result.loc[:, ['mujirushi_appetite','mujirushi_dryness', 'mujirushi_stickiness', 'mujirushi_juicy', 'mujirushi_saltiness', 'mujirushi_seasoned_flavour', 'mujirushi_flavour_heaviness', 'mujirushi_flavour_lightness', 'mujirushi_soya_taste', 'mujirushi_soya_smell','mujirushi_meat_similarity','mujirushi_meat_taste_similarity','mujirushi_meat_texture_similarity','mujirushi_meat_smell_similarity', 'mujirushi_deliciousness']]
table_mujirushi_4.columns=columns_4
table_carlota_4 = questionnaire_result.loc[:, ['carlota_appetite','carlota_dryness', 'carlota_stickiness', 'carlota_juicy', 'carlota_saltiness', 'carlota_seasoned_flavour', 'carlota_flavour_heaviness', 'carlota_flavour_lightness', 'carlota_quinoa_taste', 'carlota_quinoa_smell','carlota_meat_similarity','carlota_meat_taste_similarity','carlota_meat_texture_similarity','carlota_meat_smell_similarity', 'carlota_deliciousness']]
table_carlota_4.columns=columns_4
table_topvalue_4 = questionnaire_result.loc[:, ['topvalue_appetite','topvalue_dryness', 'topvalue_stickiness', 'topvalue_juicy', 'topvalue_saltiness', 'topvalue_seasoned_flavour', 'topvalue_flavour_heaviness', 'topvalue_flavour_lightness', 'topvalue_soya_taste', 'topvalue_soya_smell','topvalue_meat_similarity','topvalue_meat_taste_similarity','topvalue_meat_texture_similarity','topvalue_meat_smell_similarity', 'topvalue_deliciousness']]
table_topvalue_4.columns=columns_4

# %%
table_4=pd.concat([table_mogi_4,table_mujirushi_4,table_carlota_4,table_topvalue_4])

# %%
table_4
# Out:
#    appetite dryness stickiness juicy saltiness seasoned_flavour  \
# 0         3       2          3     1         3                2
# 1         3       3          3     3         3                2
# 2         3       3          3     2         3                2
# 3         4       3          3     3         2                3
# 4         4       2          3     1         3                2
# 5         4       3          3     2         2                2
# 6         4       3          3     2         2                3
# 7         3       3          3     2         3                2
# 8         4       3          3     2         3                2
# 9         5       3          3     3         3                3
# 10        4       3          3     2         3                2
# 0         3       3          3     2         3                3
# 1         3       3          3     2         3                2
# 2         4       2          3     2         3                2
# ...

# %%
X_4=np.array(table_4.loc[:,['appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity']])
y_4=np.array(table_4.loc[:,["deliciousness"]])

# %%
reg_4 = LinearRegression().fit(X_4, y_4)

# %%
print("係数は",reg_4.coef_)
print("切片は",reg_4.intercept_)
# Out:
# 係数は [[ 0.30399207 -0.51044352 -0.28287433  0.1933503   0.03103075  0.34020727
#   -0.12203051 -0.00774641 -0.0431011   0.07862021  0.26507823  0.20479498
#    0.29535181]]
# 切片は [1.46857116]

# %% [markdown]
# 美味しさに重要な項目。1位パサパサさ(どうやらパサパサの方がいいらしい)、2位旨味、3位見た目、4位肉との匂いの類似度。
# 仮説では重要だと思われていたが、実際には係数が大きくなかった、もしくは負だったものとして、[大豆の味、大豆の匂い]が挙げられる。
# 【重要1】
# ただし、項目ごとに3段階評価のものと5段階評価のものがあり、スケーリングの必要がある。(完)
# 　【重要2】
# パサパサさ1位の理由を定性的に説明することが問われる。

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

# %%
#標準正規化したものでやってみる
#まずtable_4を標準正規化する

table_4_scaled=sc.fit_transform(table_4)
table_4_scaled=pd.DataFrame(data=table_4_scaled,columns=columns_4)

X_4_scaled=np.array(table_4_scaled.loc[:,['appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity']])
y_4_scaled=np.array(table_4_scaled.loc[:,["deliciousness"]])
reg_4_scaled = LinearRegression().fit(X_4_scaled, y_4_scaled)
print("係数は",reg_4_scaled.coef_)
print("切片は",reg_4_scaled.intercept_)
# Out:
# 係数は [[ 0.30536795 -0.22514926 -0.10727511  0.10296737  0.01320597  0.18698508
#   -0.07102025 -0.00451725 -0.02147802  0.04582403  0.20169737  0.17022149
#    0.24333179]]
# 切片は [1.47408565e-17]

# %% [markdown]
# 美味しさに重要な項目。1位は「見た目」、2位は「匂いの肉との類似度」、3位は「パサパサさ」(負)

# %% [markdown]
# [見た目,肉との味の類似度,肉との食感の類似度,肉との匂いの類似度]以外の項目で美味しさの項目

# %%
#標準正規化したものでやってみる
#まずtable_4を標準正規化する
#次に、すでに標準正規化した行列をconcatしたものを使う

table_4_scaled=sc.fit_transform(table_4)
table_4_scaled=pd.DataFrame(data=table_4_scaled,columns=columns_4)

X_4_scaled=np.array(table_4_scaled.loc[:,[ 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness','meat_similarity']])
y_4_scaled=np.array(table_4_scaled.loc[:,["deliciousness"]])
reg_4_scaled = LinearRegression().fit(X_4_scaled, y_4_scaled)
print("係数は",reg_4_scaled.coef_)
print("切片は",reg_4_scaled.intercept_)
# Out:
# 係数は [[ 0.10720948  0.10909679  0.26389894 -0.18326999  0.51123428]]
# 切片は [9.16565097e-17]

# %% [markdown]
# 美味しさに重要な項目。1位は「肉との類似度」、2位は「旨味」、3位は「味の濃さ」(負)

# %% [markdown]
# 【重要3】[肉との味の類似度,肉との食感の類似度,肉との匂いの類似度]を削除し、[肉との類似度]に変えてみる。そうすることで、肉の類似度と他の要素の重要度の高さが比較できる。

# %% [markdown]
# 罰則項付きの回帰もしたい

# %% [markdown]
# #仮説5：「人の特性と美味しいと感じる代替肉の関係がある」の検証(一番大事)

# %%
table_mogi_5 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','mogi_deliciousness']]
table_mujirushi_5 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','mujirushi_deliciousness']]
table_carlota_5 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','carlota_deliciousness']]
table_topvalue_5 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','topvalue_deliciousness']]

# %%
table_mogi_5_1 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','mogi_deliciousness']]
table_mujirushi_5_1 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','mujirushi_deliciousness']]
table_carlota_5_1 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','carlota_deliciousness']]
table_topvalue_5_1 = questionnaire_result.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'topvalue_deliciousness']]

# %%
table_mogi_5_1_scaled = questionnaire_result_scaled.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','mogi_deliciousness']]
table_mujirushi_5_1_scaled = questionnaire_result_scaled.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','mujirushi_deliciousness']]
table_carlota_5_1_scaled = questionnaire_result_scaled.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness','carlota_deliciousness']]
table_topvalue_5_1_scaled = questionnaire_result_scaled.loc[:, [ 'sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'topvalue_deliciousness']]

# %%
X=np.array(table_mogi_5.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness']])

# %%
X_5_1=np.array(table_mogi_5_1.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness']])

# %%
X_5_1_scaled=np.array(table_mogi_5_1_scaled.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness']])

# %% [markdown]
# 茂木食品

# %%
y_mogi=np.array(table_mogi_5.loc[:,["mogi_deliciousness"]])
reg_5_mogi = LinearRegression().fit(X, y_mogi)
print("係数は",reg_5_mogi.coef_)
print("切片は",reg_5_mogi.intercept_)
# Out:
# 係数は [[ 0.25289773  0.05908156 -0.11455836 -0.3212076   0.02061951  0.11674244
#    0.22482201  0.29121105  0.02966255 -0.13469231  0.00125067  0.16379602
#   -0.30163077  0.48952505 -0.36357571]]
# 切片は [2.58691641]

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
y_mogi=np.array(table_mogi_5_1.loc[:,["mogi_deliciousness"]])
reg_5_1_mogi = LinearRegression().fit(X_5_1, y_mogi)
print("係数は",reg_5_1_mogi.coef_)
print("切片は",reg_5_1_mogi.intercept_)
# Out:
# 係数は [[ 0.68784772 -0.16519421 -0.94993754  0.01492633 -0.45180172 -0.08722375
#    0.01153603  1.23121008 -0.31504353  0.04005254 -0.18929335  0.55345276]]
# 切片は [2.39065076]

# %% [markdown]
# 茂木食品の『サラダバーグ』を美味しいと感じるのに需要な項目。1位が「大豆が好きかどうか」、2位が「しょっぱいものが好きか」(負)、3位が「甘いものが好きか」。

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
#標準化
y_mogi_scaled=np.array(table_mogi_5_1_scaled.loc[:,["mogi_deliciousness"]])
reg_5_1_mogi_scaled = LinearRegression().fit(X_5_1_scaled, y_mogi_scaled)
print("係数は",reg_5_1_mogi_scaled.coef_)
print("切片は",reg_5_1_mogi_scaled.intercept_)
# Out:
# 係数は [[ 1.05848914 -0.2292812  -1.37279736 -0.13976745 -0.6213074  -0.24148481
#   -0.11857421  1.26374668 -0.76087526  0.15130201 -0.46713082  1.12324026]]
# 切片は [-6.25589774e-16]

# %% [markdown]
# 標準化で結果が変わった。茂木食品の『サラダバーグ』を美味しいと感じるのに需要な項目。
# 1位は「しょっぱいものが好きか」(負)
# 2位は僅差で「大豆が好きか」
# 3位は僅差で「健康に気をつけているか」
# 4位は僅差で「甘いものが好きかどうか」

# %% [markdown]
# 無印良品

# %%
y_mujirushi=np.array(table_mujirushi_5.loc[:,["mujirushi_deliciousness"]])
reg_5_mujirushi = LinearRegression().fit(X, y_mujirushi)
print("係数は",reg_5_mujirushi.coef_)
print("切片は",reg_5_mujirushi.intercept_)
# Out:
# 係数は [[ 0.0255559  -0.08303942  0.21321782 -0.07458888 -0.03626996 -0.07978975
#   -0.46475992  0.08420994  0.35022254  0.10251842  0.20363227  0.12133341
#    0.04062427 -0.19346285  0.01183688]]
# 切片は [1.85362156]

# %%
X_1=np.array(table_mogi_5.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness']])

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
y_mujirushi=np.array(table_mujirushi_5_1.loc[:,["mujirushi_deliciousness"]])
reg_5_1_mujirushi = LinearRegression().fit(X_1, y_mujirushi)
print("係数は",reg_5_1_mujirushi.coef_)
print("切片は",reg_5_1_mujirushi.intercept_)
# Out:
# 係数は [[-0.04443128  0.05953791  0.45208827 -0.33086493  0.03924763  0.02199348
#   -0.41328495 -0.34212085  0.44653436  0.03495261  0.2899141   0.03450829]]
# 切片は [2.02969491]

# %% [markdown]
# 無印良品の『大豆ミート ハンバーグ』を美味しいと感じるのに重要な項目。1位が「しょっぱいものが好きか」、2位が僅差で「野菜の味が好きか」、3位が「濃い味が好きか」(負)。
# ・「大豆が好きか」に対しては負の係数がついた。

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
#標準化
y_mujirushi_scaled=np.array(table_mujirushi_5_1_scaled.loc[:,["mujirushi_deliciousness"]])
reg_5_1_mujirushi_scaled = LinearRegression().fit(X_5_1_scaled, y_mujirushi_scaled)
print("係数は",reg_5_1_mujirushi_scaled.coef_)
print("切片は",reg_5_1_mujirushi_scaled.intercept_)
# Out:
# 係数は [[-0.0474631   0.05137591  0.68084023 -0.3320366   0.02301449  0.10457051
#   -0.72843972 -0.28879549  0.61507079 -0.03424957  0.55162355  0.09521907]]
# 切片は [-4.01850147e-17]

# %% [markdown]
# 無印良品の『大豆ミート ハンバーグ』を美味しいと感じるのに重要な項目。
# 1位は「濃い味が好きか」(負)
# 2位は「しょっぱいものが好きか」
# 3位は「野菜が好きか」
# 依然として、「大豆が好きか」については負の係数がついている。

# %% [markdown]
# carlota(カルロタ)

# %%
y_carlota=np.array(table_carlota_5.loc[:,["carlota_deliciousness"]])
reg_5_carlota = LinearRegression().fit(X, y_carlota)
print("係数は",reg_5_carlota.coef_)
print("切片は",reg_5_carlota.intercept_)
# Out:
# 係数は [[ 0.32421279 -0.64468587 -0.06788663 -0.97995937 -0.10874913 -0.12384424
#    1.04328392  0.35219728  0.57839076  0.58563421 -0.31065178 -0.04835416
#    0.49618895  0.21432373 -0.7156228 ]]
# 切片は [-1.00305398]

# %%
X_1=np.array(table_mogi_5.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness']])

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
y_carlota=np.array(table_carlota_5_1.loc[:,["carlota_deliciousness"]])
reg_5_1_carlota = LinearRegression().fit(X_1, y_carlota)
print("係数は",reg_5_1_carlota.coef_)
print("切片は",reg_5_1_carlota.intercept_)
# Out:
# 係数は [[ 0.61344787 -1.18202014 -0.06683205  0.02147512  0.34145438 -0.90865669
#    1.20442091  2.02354858  0.88484893  0.70408768 -0.97774733 -0.49977784]]
# 切片は [-7.54165432]

# %% [markdown]
# carlota(カルロタ)の『有機ベジハンバーグ キヌア入り』を美味しいと感じるのに重要な項目。1位が「大豆が好きか」、2位が「濃い味を好むか」、3位が「辛い味を好むか」(負)
# 【重要】carlotaは評判が非常に悪く、美味しいと答えた人が少ない。データが壊れてる可能性あり(味が好きと答えた人の性質に偏る)

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
#標準化
y_carlota_scaled=np.array(table_carlota_5_1_scaled.loc[:,["carlota_deliciousness"]])
reg_5_1_carlota_scaled = LinearRegression().fit(X_5_1_scaled, y_carlota_scaled)
print("係数は",reg_5_1_carlota_scaled.coef_)
print("切片は",reg_5_1_carlota_scaled.intercept_)
# Out:
# 係数は [[ 0.56413678 -1.29084672 -0.10658114 -0.12479397  0.72070456 -1.36366141
#    1.45464276  1.35602642  0.62277426  0.69330516 -1.43740651 -0.78130101]]
# 切片は [-7.41654725e-16]

# %% [markdown]
# carlota(カルロタ)の『有機ベジハンバーグ キヌア入り』を美味しいと感じるのに重要な項目。
# 1位は「濃い味を好むか」
# 2位は僅差で「油っぽいものが好きか」(負)
# 3位は「軽い味が好きか」(負)
# 4位は「大豆が好きか」
# 濃い味を好む人は、carlotaが好きな傾向にありそう。

# %% [markdown]
# イオン topvalue

# %%
y_topvalue=np.array(table_topvalue_5.loc[:,["topvalue_deliciousness"]])
reg_5_topvalue = LinearRegression().fit(X, y_topvalue)
print("係数は",reg_5_topvalue.coef_)
print("切片は",reg_5_topvalue.intercept_)
# Out:
# 係数は [[ 0.0544364  -0.15997076  0.32388577  0.56940036 -0.05640387  0.50383514
#   -0.17136468 -0.16124622 -0.34695918  0.27251269  0.04784269 -0.31777652
#    0.42659086  0.22580503  0.32618118]]
# 切片は [-2.09125427]

# %%
X_1=np.array(table_mogi_5.loc[:,['sweet_fondness', 'spicy_fondness', 'salty_fondness', 'seasoned_flavour_fondness', 'bitter_fondness', 'light_seasoning_fondness', 'heavy_seasoning_fondness', 'soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness']])

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
y_topvalue=np.array(table_topvalue_5_1.loc[:,["topvalue_deliciousness"]])
reg_5_1_topvalue = LinearRegression().fit(X_1, y_topvalue)
print("係数は",reg_5_1_topvalue.coef_)
print("切片は",reg_5_1_topvalue.intercept_)
# Out:
# 係数は [[-0.22023748 -0.65444699  0.49417725  1.57503735  0.46048514  0.10923494
#   -0.0354597   0.89982356 -0.18009157  0.35644189 -0.25968956 -0.6453257 ]]
# 切片は [-4.49056157]

# %% [markdown]
# イオンの『大豆からつくったハンバーグ』を美味しいと感じるのに重要な項目。1位は「旨味のあるものが好きか」、2位は「大豆が好きか」、3位が「辛いものが好きか」(負)。味の旨さのアンケートで十分にあるが45.5%と、旨味の評価が高い。

# %%
#環境への配慮、代替肉への理解など、全体に関わる事項を削除して分析
#標準化
y_topvalue_scaled=np.array(table_topvalue_5_1_scaled.loc[:,["topvalue_deliciousness"]])
reg_5_1_topvalue_scaled = LinearRegression().fit(X_5_1_scaled, y_topvalue_scaled)
print("係数は",reg_5_1_topvalue_scaled.coef_)
print("切片は",reg_5_1_topvalue_scaled.intercept_)
# Out:
# 係数は [[-0.14970279 -0.53097374  0.23020751  0.88032123  0.33742371  0.04703004
#   -0.02068475  0.35286879  0.00257029  0.18377129 -0.20624575 -0.63735799]]
# 切片は [-3.58998378e-16]

# %% [markdown]
# イオンの『大豆からつくったハンバーグ』を美味しいと感じるのに重要な項目。
# 1位は「旨味のあるものが好きか」、
# 2位は「健康に気を使っているか」(負)、
# 3位は「辛いものが好きか」(負)、
# 4位は「大豆が好きか」
# という結果になった。

# %% [markdown]
# 現時点での仮説５の総評：「大豆が好きか」、「濃い味が好きか」、「辛いものが好きか」の係数が大きかった。それ以外も、1位2位3位になった項目を集めてそれだけで分析をしてみたい。多重線形性

# %% [markdown]
# 多重線形性を考慮して分析したい

# %% [markdown]
# 罰則項付きの回帰もしたい

# %%
#一番評価が高いもので決定木クラス分類

# %% [markdown]
# #仮説7：「もう一度代替肉を消費したいと思うために重要な項目がある」の検証

# %% [markdown]
# まず商品ごと

# %%
columns_7=['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','price','brand_cognition','package_impression','appetite','appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness','willingness_to_buy_X']
table_mogi_7 = questionnaire_result.loc[:, ['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','mogi_price','mogi_brand_cognition','mogi_package_impression','mogi_appetite','mogi_appetite','mogi_dryness', 'mogi_stickiness', 'mogi_juicy', 'mogi_saltiness', 'mogi_seasoned_flavour', 'mogi_flavour_heaviness', 'mogi_flavour_lightness', 'mogi_soya_taste', 'mogi_soya_smell','mogi_meat_taste_similarity','mogi_meat_texture_similarity','mogi_meat_smell_similarity', 'mogi_deliciousness','willingness_to_buy_A'] ]
table_mogi_7.columns=columns_7
table_mujirushi_7 = questionnaire_result.loc[:, ['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','mujirushi_price','mujirushi_brand_cognition','mujirushi_package_impression','mujirushi_appetite','mujirushi_appetite','mujirushi_dryness', 'mujirushi_stickiness', 'mujirushi_juicy', 'mujirushi_saltiness', 'mujirushi_seasoned_flavour', 'mujirushi_flavour_heaviness', 'mujirushi_flavour_lightness', 'mujirushi_soya_taste', 'mujirushi_soya_smell','mujirushi_meat_taste_similarity','mujirushi_meat_texture_similarity','mujirushi_meat_smell_similarity', 'mujirushi_deliciousness','willingness_to_buy_B']]
table_mujirushi_7.columns=columns_7
table_carlota_7 = questionnaire_result.loc[:, ['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','carlota_price','carlota_brand_cognition','carlota_package_impression','carlota_appetite','carlota_appetite','carlota_dryness', 'carlota_stickiness', 'carlota_juicy', 'carlota_saltiness', 'carlota_seasoned_flavour', 'carlota_flavour_heaviness', 'carlota_flavour_lightness', 'carlota_quinoa_taste', 'carlota_quinoa_smell','carlota_meat_taste_similarity','carlota_meat_texture_similarity','carlota_meat_smell_similarity', 'carlota_deliciousness','willingness_to_buy_C'] ]
table_carlota_7.columns=columns_7
table_topvalue_7 = questionnaire_result.loc[:, ['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','topvalue_price','topvalue_brand_cognition','topvalue_package_impression','topvalue_appetite','topvalue_appetite','topvalue_dryness', 'topvalue_stickiness', 'topvalue_juicy', 'topvalue_saltiness', 'topvalue_seasoned_flavour', 'topvalue_flavour_heaviness', 'topvalue_flavour_lightness', 'topvalue_soya_taste', 'topvalue_soya_smell','topvalue_meat_taste_similarity','topvalue_meat_texture_similarity','topvalue_meat_smell_similarity', 'topvalue_deliciousness','willingness_to_buy_D'] ]
table_topvalue_7.columns=columns_7

# %%
table_7=pd.concat([table_mogi_7,table_mujirushi_7,table_carlota_7,table_topvalue_7])
table_7=sc.fit_transform(table_7)
table_7=pd.DataFrame(data=table_7,columns=columns_7)
table_7_0=table_7.iloc[:,8:]
#table_7_0=sc.fit_transform(table_7_0)
#table_7_0=pd.DataFrame(data=table_7_0,columns=table_7.iloc[:,8:].columns)
#table_7_0
table_7
# Out:
#     soya_bean_fondness  vegetable_fondness  meat_fondness  oily_fondness  \
# 0            -1.095445           -0.581238      -0.912871      -0.471405
# 1            -1.095445            0.697486      -0.912871      -1.335646
# 2             0.912871            0.697486       1.095445       0.392837
# 3             0.912871            0.697486      -0.912871      -0.471405
# 4             0.912871           -1.859962       1.095445       1.257079
# 5             0.912871            0.697486       1.095445       0.392837
# 6            -1.095445           -0.581238      -0.912871       0.392837
# 7             0.912871            0.697486      -0.912871       0.392837
# 8            -1.095445           -1.859962       1.095445       0.392837
# 9            -1.095445            0.697486       1.095445      -2.199888
# 10            0.912871            0.697486      -0.912871       1.257079
# 11           -1.095445           -0.581238      -0.912871      -0.471405
# ...

# %%
#共通項目を削除した結果
X_7_0=np.array(table_7_0.loc[:,['price','brand_cognition','package_impression','appetite','appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness']])
y_7_0=np.array(table_7_0.loc[:,['willingness_to_buy_X']])
reg_7_0 = LinearRegression().fit(X_7_0, y_7_0)
print("係数は",reg_7_0.coef_)
print("切片は",reg_7_0.intercept_)
# Out:
# 係数は [[ 0.36915429 -0.3480803  -0.05272651  0.01567057  0.01567057  0.01567057
#    0.01567057  0.081993    0.1050614  -0.06089102 -0.15293145 -0.03594813
#    0.10575299  0.01322855 -0.1477283   0.01341495  0.05279752 -0.02930502
#   -0.09730399  0.76163285]]
# 切片は [1.46227351e-16]

# %%
#共通項目を削除した結果
#標準化を施した結果
X_7_0=np.array(table_7_0.loc[:,['price','brand_cognition','package_impression','appetite','appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness']])
y_7_0=np.array(table_7_0.loc[:,['willingness_to_buy_X']])
reg_7_0 = LinearRegression().fit(X_7_0, y_7_0)
print("係数は",reg_7_0.coef_)
print("切片は",reg_7_0.intercept_)
# Out:
# 係数は [[ 0.36915429 -0.3480803  -0.05272651  0.01567057  0.01567057  0.01567057
#    0.01567057  0.081993    0.1050614  -0.06089102 -0.15293145 -0.03594813
#    0.10575299  0.01322855 -0.1477283   0.01341495  0.05279752 -0.02930502
#   -0.09730399  0.76163285]]
# 切片は [1.46227351e-16]

# %% [markdown]
# 再度購入したいかに重要な項目。
# 1位美味しさ2位価格。ほぼ予想通りの結果となった。
# ブランド認知の係数は今回は負になった。無印の評価が低かったのが影響したと考えられる。

# %%
X_7=np.array(table_7.loc[:,['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','price','brand_cognition','package_impression','appetite','appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness']])
y_7=np.array(table_7.loc[:,['willingness_to_buy_X']])

# %%
reg_7 = LinearRegression().fit(X_7, y_7)
print("係数は",reg_7.coef_)
print("切片は",reg_7.intercept_)
# Out:
# 係数は [[ 0.00643606  0.72031555  0.04972545  0.20191472 -0.43373819 -0.51176179
#    0.75224162 -0.26895141  0.33517593 -0.30439201 -0.19599443  0.06878329
#    0.06878329  0.06878329  0.06878329 -0.06482118  0.18128209 -0.24439051
#    0.01784216  0.14279237 -0.02407023  0.02444446 -0.18129048  0.052729
#    0.15811419  0.03324658  0.21139027  0.28246616]]
# 切片は [1.69905922e-16]

# %% [markdown]
# 1位が「環境に配慮しているか」(負)、2位が「野菜の味を好むか」、3位が「代替肉に対する認識度」

# %%
#標準化
X_7=np.array(table_7.loc[:,['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness','price','brand_cognition','package_impression','appetite','appetite','dryness', 'stickiness', 'juicy', 'saltiness', 'seasoned_flavour', 'flavour_heaviness', 'flavour_lightness', 'soya_taste', 'soya_smell','meat_taste_similarity','meat_texture_similarity','meat_smell_similarity', 'deliciousness']])
y_7=np.array(table_7.loc[:,['willingness_to_buy_X']])
reg_7 = LinearRegression().fit(X_7, y_7)
print("係数は",reg_7.coef_)
print("切片は",reg_7.intercept_)
# Out:
# 係数は [[ 0.00643606  0.72031555  0.04972545  0.20191472 -0.43373819 -0.51176179
#    0.75224162 -0.26895141  0.33517593 -0.30439201 -0.19599443  0.06878329
#    0.06878329  0.06878329  0.06878329 -0.06482118  0.18128209 -0.24439051
#    0.01784216  0.14279237 -0.02407023  0.02444446 -0.18129048  0.052729
#    0.15811419  0.03324658  0.21139027  0.28246616]]
# 切片は [1.69905922e-16]

# %% [markdown]
# ある代替肉商品を再度消費したいと思うのに大切な事項。
# 1位は「代替肉に対する認識度」
# 2位は「野菜の味が好きか」
# 3位は「代替肉に対する印象」

# %% [markdown]
# 代替肉全般

# %%
table_7=pd.concat([table_mogi_7,table_mujirushi_7,table_carlota_7,table_topvalue_7])
table_7_2=table_7.iloc[:,:8]
table_7_2
# Out:
#    soya_bean_fondness vegetable_fondness meat_fondness oily_fondness  \
# 0                   3                  3             4             3
# 1                   3                  4             4             2
# 2                   4                  4             5             4
# 3                   4                  4             4             3
# 4                   4                  2             5             5
# 5                   4                  4             5             4
# 6                   3                  3             4             4
# 7                   4                  4             4             4
# 8                   3                  2             5             4
# 9                   3                  4             5             1
# 10                  4                  4             4             5
# 0                   3                  3             4             3
# 1                   3                  4             4             2
# ...

# %%
#共通部分のみ
X_7_2=np.array(questionnaire_result.loc[:,['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness']])
y_7_2=np.array(questionnaire_result.loc[:,['willingness_to_buy_fake_meat']])
reg_7_2 = LinearRegression().fit(X_7_2, y_7_2)
print("係数は",reg_7_2.coef_)
print("切片は",reg_7_2.intercept_)
# Out:
# 係数は [[-0.05367244  1.34305614  0.08406501  0.57121148 -0.61116505 -0.47207683
#    0.7850992  -0.64065006]]
# 切片は [-0.28146897]

# %% [markdown]
# 代替肉を買いたいかに重要な要素について。1位が「野菜の味が好きか」、2位が「代替肉への認知度」、3位が「環境への配慮」(係数負)、僅差で4位が「健康への配慮」(係数負)

# %%
#共通部分のみ
#標準化
X_7_2=np.array(questionnaire_result_scaled.loc[:,['soya_bean_fondness', 'vegetable_fondness', 'meat_fondness','oily_fondness','health_awareness', 'fake_meat_impression', 'fake_meat_cognition', 'environmental_awareness']])
y_7_2=np.array(questionnaire_result_scaled.loc[:,['willingness_to_buy_fake_meat']])
reg_7_2 = LinearRegression().fit(X_7_2, y_7_2)
print("係数は",reg_7_2.coef_)
print("切片は",reg_7_2.intercept_)
# Out:
# 係数は [[-0.0309878   1.2178359   0.04853495  0.76636062 -0.75679246 -0.58456252
#    1.05332111 -0.21355002]]
# 切片は [1.33499066e-16]

# %% [markdown]
# 任意の代替肉を購入したいと思うのに重要な項目について。
# 1位が「野菜が好きかどうか」
# 2位が「代替肉への認識度」
# 3位が「油っぽいものを好むか」
# 4位が僅差で「健康への配慮」(負)
